# %% [markdown]
# # Exercise 5: Generate forcing for any region from CMIP6 for HBV model
#
# In this notebook you will generate forcing from CMIP6 for your own HBV model. For forcing generation we use the eWaterCycle generic forcing generator. This will download the required CMIP6 data from a remote ESGF server
#
# You have to supply your own shapefile. Upload it inside the "Forcing" directory, see the file browser on your left (if you have done the previous exercises, you have already uploaded it). We have uploaded a shapefile for the Rhine, to be able to test this notebook ourselves.
#
# We have seperated generating the forcing and running the model into two notebooks because generating the forcing is quite heavy on the hardware and we want to minimize the number of times you have to do that. After generating your forcing in this notebook, it will be saved so we can load it later without having to re-run it.
#
# Once you have this forcing, you can change the other notebooks to run your model using this forcing.

# %%
# Required dependencies, note that we do not need to import the model for only generating forcing
import ewatercycle.forcing
import ewatercycle.observation.grdc
import ewatercycle.analysis
from pathlib import Path
from cartopy.io import shapereader
import pandas as pd
import numpy as np
from rich import print
import xarray as xr
import shutil
# Out:
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498

# %%
# Name of your shapefile/region without extension:
own_region = "emporda_dissolved"  # for example: "Rhine"

if own_region == None:  # if nothing is provided, the Rhine shapefile will be used
    own_region = "emporda_dissolved"

# %%
# Shapefile that describes the basin we want to study.
path = Path.cwd()
forcing_path = path / "Forcing"
shapeFile = forcing_path / f"{own_region}.shp"

# Location to save forcing results
saveLocation = forcing_path / f"{own_region}ForcingCMIP"

# Period of interest. 
# Make sure that ERA5 is available on your machine for this period. 
# On our machine ERA5 is available from 1990 up until 2019.
# For the course ENVM1502 ERA5 is available from 2010-01-01 until 2014-12-31
# Choose a period for which you have observation data of discharge available!
experiment_start_time = "2001-01-01T00:00:00Z"
experiment_end_time = "2010-12-31T00:00:00Z"

# %%
# CMIP6 information, you can change this, but do research on what this means before changing anything!

cmip_dataset = {
    "dataset": "MPI-ESM1-2-HR",
    "project": "CMIP6",
    "grid": "gn",
    "frequency":"day",
    "exp": "historical",
    "ensemble": "r1i1p1f1",
}

# %% [markdown]
# Forcing is created using the LumpedMakkinkForcing option in eWaterCycle. This selects rainfall and precipitation from the indicated dataset for the given time period and averages over the indicated shape. It calculates potential evaporation using the approximation by Makkink. The result is two NetCDF files and a yaml file. This can later be loaded using ```ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(forcingLocation)```. Depending on how busy the machine is and how big the area is you are generating forcing for, the cell below can take minutes to run.

# %%
CMIP6_forcing = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
    dataset=cmip_dataset,
    start_time=experiment_start_time,
    end_time=experiment_end_time,
    shape=shapeFile.absolute(),
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 CMIP6_forcing = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
#       2     dataset=cmip_dataset,
#       3     start_time=experiment_start_time,
#       4     end_time=experiment_end_time,
#       5     shape=shapeFile.absolute(),
#       6 )
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/_forcings/makkink.py:57, in Makkink.generate(cls, dataset, start_time, end_time, shape, directory, **model_specific_options)
#      47 @classmethod
#      48 def generate(  # type: ignore[override]
#      49     cls: type["Makkink"],
#    (...)
#      55     **model_specific_options,
#      56 ) -> "Makkink":
# ---> 57     return super().generate(
#      58         dataset,
#      59         start_time,
#      60         end_time,
#      61         shape,
#      62         directory,
#      63         variables=("pr", "tas", "rsds"),
#      64         postprocessor=derive_e_pot,
#      65         **model_specific_options,
#      66     )
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/forcing.py:162, in DefaultForcing.generate(cls, dataset, start_time, end_time, shape, directory, variables, postprocessor, **model_specific_options)
#     129 """Generate forcings for a model.
#     130
#     131 The forcing is generated with help of
#    (...)
#     151     model_specific_options: Subclass specific options.
#     152 """
#     153 recipe = cls._build_recipe(
#     154     dataset=dataset,
#     155     start_time=get_time(start_time),
#    (...)
#     159     **model_specific_options,
#     160 )
# --> 162 recipe_output = cls._run_recipe(
#     163     recipe, directory=Path(directory) if directory else None
#     164 )
#     166 derived_variables: tuple[str, ...] = ()
#     167 if postprocessor is not None:
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/forcing.py:217, in DefaultForcing._run_recipe(cls, recipe, directory)
#     211 @classmethod
#     212 def _run_recipe(
#     213     cls,
#     214     recipe: Recipe,
#     215     directory: Path | None = None,
#     216 ) -> dict[str, str]:
# --> 217     return run_recipe(recipe, directory)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/esmvaltool/run.py:109, in run_recipe(recipe, output_dir)
#     100 warnings.filterwarnings(  # Not relevant for end users.
#     101     action="ignore",
#     102     message="Thank you for trying out the new ESMValCore API",
#     103 )
#     104 warnings.filterwarnings(  # Hide Iris warning (upstream issue)
#     105     action="ignore",
#     106     message="Saving to netcdf with legacy-style attribute",
#     107 )
# --> 109 output = _save_and_run_recipe(recipe, output_dir)
#     110 return _parse_recipe_output(output)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/esmvaltool/run.py:137, in _save_and_run_recipe(recipe, output_dir)
#     135     esmlvaltool_recipe = ESMValToolRecipe(recipe_path)
#     136     session = _session(output_dir)
# --> 137     output = esmlvaltool_recipe.run(session=session)
#     138 finally:
#     139     recipe_path.unlink()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/recipe.py:137, in Recipe.run(self, task, session)
#     135 with log_to_dir(session.run_dir):
#     136     _dask.check_distributed_config()
# --> 137     self._engine = self._load(session=session)
#     138     self._engine.run()
#     140 shutil.copy2(self.path, session.run_dir)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/recipe.py:97, in Recipe._load(self, session)
#      78 """Load the recipe.
#      79
#      80 This method loads the recipe into the internal ESMValCore Recipe
#    (...)
#      93     Return an instance of the Recipe
#      94 """
#      95 logger.info(pprint.pformat(session))
# ---> 97 return RecipeEngine(raw_recipe=self.data,
#      98                     session=session,
#      99                     recipe_file=self.path)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:740, in Recipe.__init__(self, raw_recipe, session, recipe_file)
#     737 self.entity = self._initialize_provenance(
#     738     raw_recipe.get('documentation', {}))
#     739 try:
# --> 740     self.tasks = self.initialize_tasks()
#     741 except RecipeError as exc:
#     742     self._log_recipe_errors(exc)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:1066, in Recipe.initialize_tasks(self)
#    1064 def initialize_tasks(self):
#    1065     """Define tasks in recipe."""
# -> 1066     tasks = self._create_tasks()
#    1067     tasks = tasks.flatten()
#    1068     logger.info("These tasks will be executed: %s",
#    1069                 ', '.join(t.name for t in tasks))
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:1041, in Recipe._create_tasks(self)
#    1038     priority += 1
#    1040 # Create preprocessor tasks
# -> 1041 new_tasks, failed = self._create_preprocessor_tasks(
#    1042     diagnostic_name, diagnostic, tasknames_to_run,
#    1043     any_diag_script_is_run)
#    1044 failed_tasks.extend(failed)
#    1045 for task in new_tasks:
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:1005, in Recipe._create_preprocessor_tasks(self, diagnostic_name, diagnostic, tasknames_to_run, any_diag_script_is_run)
#    1003 logger.info("Creating preprocessor task %s", task_name)
#    1004 try:
# -> 1005     task = _get_preprocessor_task(
#    1006         datasets=list(datasets),
#    1007         profiles=self._preprocessors,
#    1008         task_name=task_name,
#    1009     )
#    1010 except RecipeError as exc:
#    1011     failed_tasks.append(exc)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:679, in _get_preprocessor_task(datasets, profiles, task_name)
#     676 order = _extract_preprocessor_order(profile)
#     678 # Create preprocessor task
# --> 679 products = _get_preprocessor_products(
#     680     datasets=datasets,
#     681     profile=profile,
#     682     order=order,
#     683     name=task_name,
#     684 )
#     686 if not products:
#     687     raise RecipeError(f"Did not find any input data for task {task_name}")
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:525, in _get_preprocessor_products(datasets, profile, order, name)
#     523 check.preprocessor_supplementaries(dataset, settings)
#     524 input_datasets = _get_input_datasets(dataset)
# --> 525 missing = _check_input_files(input_datasets)
#     526 if missing:
#     527     if _allow_skipping(dataset):
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:294, in _check_input_files(input_datasets)
#     292 for dataset in [input_dataset] + input_dataset.supplementaries:
#     293     try:
# --> 294         check.data_availability(dataset)
#     295     except RecipeError as exc:
#     296         missing.add(exc.message)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/check.py:188, in data_availability(dataset, log)
#     185 available_years = set()
#     187 for file in input_files:
# --> 188     start, end = _get_start_end_year(file)
#     189     available_years.update(range(start, end + 1))
#     191 missing_years = required_years - available_years
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/local.py:160, in _get_start_end_year(file)
#     154 def _get_start_end_year(
#     155         file: str | Path | LocalFile | ESGFFile) -> tuple[int, int]:
#     156     """Get the start and end year as int from a file name.
#     157
#     158     See :func:`_get_start_end_date`.
#     159     """
# --> 160     (start_date, end_date) = _get_start_end_date(file)
#     161     return (int(start_date[:4]), int(end_date[:4]))
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/local.py:143, in _get_start_end_date(file)
#     140         break
#     142 if start_date is None or end_date is None:
# --> 143     raise ValueError(
#     144         f"File {file} datetimes do not match a recognized pattern and "
#     145         f"time coordinate can not be read from the file")
#     147 # Remove potential '-' characters from datetimes
#     148 start_date = start_date.replace('-', '')
#
# ValueError: File ESGFFile:CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/historical/r1i1p1f1/fx/areacella/gn/v20190710/areacella_fx_MPI-ESM1-2-HR_historical_r1i1p1f1_gn.nc on hosts ['esgf.ceda.ac.uk'] datetimes do not match a recognized pattern and time coordinate can not be read from the file

# %%
print(CMIP6_forcing)

# %% [markdown]
# Let's make a plot to look at this forcing

# %%
CMIP6_forcing.to_xarray()["evspsblpot"].plot(color="blue")
CMIP6_forcing.to_xarray()["pr"].plot(color="orange")

# %% [markdown]
# Finally, the forcing is saved deep in an ESMValTool directory that was just created. For easy loading in other notebooks, let's save it in a better location.

# %%
shutil.copytree(CMIP6_forcing.directory,saveLocation)
